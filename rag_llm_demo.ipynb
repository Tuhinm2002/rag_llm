# %% [markdown]
# <a href="https://colab.research.google.com/github/Tuhinm2002/rag_llm/blob/main/rag_llm_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install langchain_community langchain-huggingface langchain -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 51.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 61.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.3/423.3 kB 33.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 109.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 829.5 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 67.7 MB/s eta 0:00:00

# %%
! pip install faiss-cpu -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 62.5 MB/s eta 0:00:00

# %%
import faiss
from langchain.chains import RetrievalQA
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain_huggingface import HuggingFaceEndpoint
from langchain.text_splitter import CharacterTextSplitter
import numpy as np

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "your_hf_token_here"

# %%
with open('text_merged.txt','r',encoding='utf-8') as file_reader:
  text = file_reader.read()
  file_reader.close()

# %%
text_splitter = CharacterTextSplitter(chunk_size=1000,chunk_overlap=200)
chunks = text_splitter.split_text(text)
# Out:
# WARNING:langchain_text_splitters.base:Created a chunk of size 2148, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1633, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2869, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3680, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3079, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2368, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3596, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1193, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1032, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3686, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3922, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1492, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2172, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3975, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4114, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1947, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2800, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1919, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3899, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3173, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4215, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2915, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4124, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4067, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1944, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1320, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4130, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4249, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3596, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1838, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1847, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3492, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2708, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3471, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3764, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2394, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2308, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3078, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2722, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1616, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1455, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1981, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3339, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3222, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2355, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3699, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4203, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4077, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3855, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3723, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3887, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1544, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4287, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2498, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3895, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1743, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2013, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3581, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3251, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4028, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4092, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2991, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3771, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3524, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3769, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1770, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2035, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3109, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3705, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3536, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3689, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3037, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2423, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3569, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3638, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4052, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4036, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4040, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4068, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3226, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3770, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2229, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4282, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2850, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4052, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2103, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1473, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3814, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4144, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2577, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1880, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3476, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3969, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3685, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3932, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2006, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1334, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2146, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1457, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2182, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2751, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3175, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3508, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1556, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3381, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2695, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3181, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3916, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2242, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1006, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1930, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1350, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3630, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2453, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2831, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3189, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2843, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3770, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2603, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3739, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3397, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3206, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1424, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1371, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3488, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1829, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1326, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3847, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3320, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2993, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1954, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1458, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2929, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2748, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2783, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3312, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3161, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3598, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1953, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1798, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4191, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4096, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4267, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3828, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1996, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3530, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2754, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3637, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3677, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3780, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1188, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2030, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3383, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1040, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2044, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3301, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3855, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1384, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1799, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3938, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3123, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2765, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3282, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2900, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3463, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3570, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1741, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4334, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3970, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4027, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3423, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2438, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3974, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3900, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2670, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3421, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3747, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3476, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4323, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1446, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2332, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4002, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3607, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4085, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3593, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1577, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1604, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4000, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3826, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3795, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3482, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4053, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4042, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2904, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3504, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3645, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2278, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3293, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3921, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3743, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4095, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4065, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4109, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3763, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4224, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4095, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3974, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4146, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1650, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3876, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3787, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4225, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2874, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2031, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4269, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4330, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4023, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4151, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3895, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3813, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1826, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4229, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1537, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1708, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3874, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2848, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3332, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3306, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3543, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4133, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3827, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2365, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1148, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3432, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3624, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3425, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2561, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1077, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3612, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3731, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2977, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3443, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3418, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3523, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1073, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1942, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4114, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4099, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1306, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3701, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3515, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1657, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1996, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3998, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4059, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4131, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4005, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3733, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3637, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4007, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3822, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4005, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4378, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3599, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3438, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4227, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4297, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3873, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4009, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4274, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4230, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3836, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4070, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3717, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4353, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3929, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4010, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3908, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3814, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4010, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3654, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4251, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4111, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4368, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4268, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4228, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3934, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3694, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4114, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3974, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4153, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4274, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3701, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1902, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3688, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2524, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1297, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3668, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1551, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2121, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1256, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1911, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3966, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1262, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2484, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3954, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2890, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4259, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3658, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2384, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3629, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3269, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3888, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2435, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3667, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3412, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3305, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2808, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3334, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2543, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1143, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2192, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1274, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3537, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4244, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3320, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2779, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2847, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2170, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3226, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3846, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2575, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3429, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3924, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3503, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1136, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2340, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4451, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4132, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4291, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4526, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4511, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4502, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4608, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4122, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4345, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4388, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4541, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4336, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4241, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4445, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3910, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4476, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4468, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4451, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4278, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4281, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4312, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4631, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4739, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4374, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4343, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4399, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4443, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4178, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4472, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4313, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4151, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3855, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4352, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4195, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4519, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4442, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4533, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3900, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4161, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1382, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3528, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2973, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3378, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3641, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1821, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1434, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2731, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3099, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3351, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2164, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2954, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3432, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3619, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2604, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2755, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3436, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2634, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3101, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2655, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1414, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1143, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3744, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4251, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3008, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3431, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2708, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4028, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3423, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1670, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3236, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2270, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3245, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3419, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1675, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2317, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4602, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3055, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2206, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3831, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2167, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4262, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3065, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2132, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4236, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4207, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3892, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4037, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4050, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4152, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2207, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4179, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2084, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3608, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2170, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2953, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1042, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3281, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2493, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2436, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2229, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2131, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2946, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2072, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3979, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1519, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3148, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2877, which is longer than the specified 1000
# ...
# WARNING:langchain_text_splitters.base:Created a chunk of size 2737, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2173, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2203, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2748, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3003, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3227, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1598, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2864, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1618, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3229, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3377, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1951, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2866, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3162, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2092, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3103, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1382, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1003, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2819, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1504, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1181, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1763, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1963, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2221, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2716, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1690, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3132, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2112, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2481, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2947, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3611, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2243, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3013, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2783, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2729, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2108, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1044, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3591, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2446, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1023, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1064, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1045, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1632, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1071, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1207, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1032, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1540, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1019, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1338, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1008, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1026, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1172, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1512, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1320, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1232, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1040, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1504, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1759, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1346, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1537, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1049, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1740, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1261, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1339, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1325, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1140, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1339, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1501, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1293, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1130, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1587, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1113, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1379, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1349, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1276, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1429, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1474, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1957, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1162, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1577, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1506, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1577, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2126, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2718, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2004, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2480, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1992, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2319, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1940, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2261, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2151, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1093, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1228, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 5076, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 6174, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1847, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1616, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1258, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1366, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1074, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1394, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2518, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2464, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2351, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1587, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2359, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2071, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2832, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1887, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2478, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3044, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1273, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3905, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3854, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2137, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1058, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 5199, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3870, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3959, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 5066, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 5392, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2911, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2349, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3076, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1115, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3010, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1890, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3383, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1481, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2115, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2910, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2726, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1442, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3360, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1498, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3485, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4071, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 5554, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2748, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1305, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4951, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2431, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 5518, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 5028, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1610, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1928, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1394, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1656, which is longer than the specified 1000

# %%
hf_embeddings = HuggingFaceEmbeddings(
    model_name = "sentence-transformers/all-mpnet-base-v2",
    model_kwargs = {'device':'cuda'},
    encode_kwargs = {'normalize_embeddings':False}
)

# %%
embeddings = hf_embeddings.embed_documents(chunks)
dimension = len(embeddings[0])

# %%
quantizer = faiss.IndexFlatL2(dimension)
index = faiss.IndexIVFFlat(quantizer, dimension, 100)
index.train(np.array(embeddings).astype('float32'))
index.add(np.array(embeddings).astype('float32'))

# %%
from langchain.schema import Document

documents = [Document(page_content=chunk) for chunk in chunks]
docstore = InMemoryDocstore({str(i): doc for i, doc in enumerate(documents)})
index_to_docstore_id = {i: str(i) for i in range(len(documents))}

vector_store = FAISS(embedding_function=hf_embeddings.embed_query,index=index, docstore=docstore, index_to_docstore_id=index_to_docstore_id)

# Step 4: Save index
vector_store.save_local('vector_search')
# Out:
# WARNING:langchain_community.vectorstores.faiss:`embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.

# %%
llm = HuggingFaceEndpoint(
    repo_id = "mistralai/Mistral-7B-Instruct-v0.2",
    task = "text-generation",
    temperature=0.6
)

# %%
vector_search = FAISS.load_local("/content/vector_search/",embeddings=hf_embeddings,
                                 allow_dangerous_deserialization=True)
query = "what is rig veda"

# %%
qa = RetrievalQA.from_chain_type(llm=llm,retriever=vector_search.as_retriever())
answer = qa({'query':query})
print(answer)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# {'query': 'what is rig veda', 'result': ' The Rigveda is the oldest and most authoritative of the four Vedas in Hinduism. It is a collection of hymns, prayers, and rituals, composed in the ancient Indo-European language of Sanskrit. It is considered the foundational text of Hinduism and contains references to various gods and goddesses, as well as mythological stories and philosophical ideas. The Rigveda is also a rich source of information about ancient Indian society, culture, and history.'}
